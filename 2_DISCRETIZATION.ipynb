# %% [markdown]
# ###########################DISCRETIZATION############################<br>
# ataset:Iris

# %% [markdown]
# Importing the necessary packages/dependencies  :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the dataset From local directory  :

# %%
    
df = pd.read_csv('C:\\Users\\Sayandeep Sinha\\Documents\\DataSets\\iris.csv')

# %% [markdown]
# Convert the continuous data into discrete classes on iris dataset.<br>
# Prepare the dataset by performing the preprocessing techniques, <br>
# to have the data which improve model performance.

# %% [markdown]
# finding the outliers with the help of boxplot:

# %%
df.boxplot(figsize=(10,6));

# %% [markdown]
# Dropping the unnecessary variable :

# %%
    
df = df.drop('Unnamed: 0', axis=1 )

# %%
df.columns

# %%
df.info()

# %% [markdown]
# Checking the relationships of the variables :

# %%
    
plt.figure(figsize=(20, 10));
sns.heatmap(df.corr().abs(),  annot=True);

# %%
df.info()

# %% [markdown]
# Converting the the continuous data ('float64') into discrete classes('int64') of sepal length:

# %%
df['Sepal.Length'].dtype

# %%
df['Sepal.Length'] = df['Sepal.Length'].astype('int64')

# %% [markdown]
# Converting the the continuous data ('float64') into discrete classes('int64') of sepal width:

# %%
df['Sepal.Width'].dtype

# %%
df['Sepal.Width'] = df['Sepal.Width'].astype('int64')

# %%
df.boxplot(column =['Sepal.Width'], grid = False) ;

# %% [markdown]
# Sepal width outliers are in natural by its nature, hence we are not treating is as outliers.

# %% [markdown]
# Converting the the continuous data ('float64') into discrete classes('int64') of petal length:

# %%
df['Petal.Length'].dtype

# %%
df['Petal.Length'] = df['Petal.Length'].astype('int64')

# %% [markdown]
# Converting the the continuous data ('float64') into discrete classes('int64') of petal width:

# %%
df['Petal.Width'].dtype

# %%
df['Petal.Width'] = df['Petal.Width'].astype('int64')

# %% [markdown]
# Mapping the categorical variable into the numerical integer as int 64 :

# %%
df.Species.value_counts()

# %%
Species_map = {'versicolor': 0, 'setosa': 1, 'virginica': 2 }

# %%
df.Species = df.Species.map(Species_map)
