# %% [markdown]
# ###########################Dummy_Variables############################<br>
# ataset:animal_category <br>
# ame: Sayandeep Sinha<br>
# atch: 09_09_21

# %% [markdown]
# Importing the necessary packages/dependencies  :

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Loading the dataset From local directory  :

# %%
    
df = pd.read_csv('C:\\Users\\Sayandeep Sinha\\Documents\\DataSets\\animal_category.csv')

# %% [markdown]
# Prepare the dataset by performing the preprocessing techniques, to have the all the features in numeric format :

# %% [markdown]
# Dropping the unnecessary variable :

# %%
    
df = df.drop('Index', axis=1 )

# %%
df.info()
    
df.columns

# %%
df.value_counts()

# %% [markdown]
# Coverting the categorical type into numerical can be done with the help  of map technique using pandas :<br>
# Animal Variable :

# %%
  
df.columns

# %%
df.Animals.unique()

# %%
Animals_map = {'Cat': 0, 'Dog': 1, 'Mouse': 2, 'Lion': 3, 'Goat': 4}

# %%
df.Animals = df.Animals.map(Animals_map)

# %% [markdown]
# Coverting the categorical type into numerical can be done with the help  of map technique using pandas :<br>
# Gender Variable :

# %%
    
df.columns

# %%
df.Gender.unique()

# %%
Gender_map = {'Male': 0, 'Female': 1}

# %%
df.Gender = df.Gender.map(Gender_map)

# %% [markdown]
# Coverting the categorical type into numerical can be done with the help  of map technique using pandas :<br>
# Homly Variable :

# %%
    
df.columns

# %%
df.Homly.unique()

# %%
Homly_map = {'Yes': 0, 'No': 1}

# %%
df.Homly = df.Homly.map(Homly_map)

# %% [markdown]
# Coverting the categorical type into numerical can be done with the help  of map technique using pandas :<br>
# Types Variable :

# %%
    
    
df.columns

# %%
df.Types.unique()

# %%
Types_map = {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4}

# %%
df.Types = df.Types.map(Types_map)
