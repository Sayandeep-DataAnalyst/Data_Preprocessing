# %% [markdown]
# ###########################:Inferential Statistics:############################<br>
# ataset: Score_points.csv

# %% [markdown]
# Importing the necessary packages/dependencies  :

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import pylab
import matplotlib.pyplot as plt

# %% [markdown]
# Q5) Calculate Mean, Median, Mode, Variance, Standard Deviation, <br>
# Range & comment about the values / draw inferences, for the given dataset

# %% [markdown]
# Loading the dataset From local directory  :

# %%
    
df = pd.read_csv("C:\\Users\\Sayandeep Sinha\\Documents\\Score_points.csv")

# %%
df.mean()#mean

# %%
df.median()#median

# %%
df.mode()#mode

# %%
np.std(df)#standard deviation

# %%
np.var(df)#variance

# %%
np.percentile(df['Points'],0.25)

# %% [markdown]
# ange=max-min

# %%
print('Score range :',np.max(df.Score)-np.min(df.Score))
print('Points range :',np.max(df.Points)-np.min(df.Points))
print('Weigh range :',np.max(df.Weigh)-np.min(df.Weigh))

# %%
np.percentile(df['Score'],0.75)

# %% [markdown]
# r#

# %% [markdown]
# we can use describe functions to find the measures of the data :

# %%
df.describe()

# %% [markdown]
# Transforming the data using the log technique :

# %%
    
df.columns    
    
       
new_df = np.log(df[['Points', 'Score', 'Weigh']])

# %%
stats.probplot(new_df['Points'], dist="norm", plot=pylab );

# %%
stats.probplot(new_df['Score'], dist="norm", plot=pylab );

# %%
stats.probplot(new_df['Weigh'], dist="norm", plot=pylab );

# %%
df_plot = df[['Points', 'Score', 'Weigh']].copy()

# %%
df_plot.plot.kde();

# %% [markdown]
# Q7)Look at the data given below. Plot the data, find the outliers and find out  Î¼,Ïƒ,Ïƒ^2

# %%
data = pd.read_csv("C:\\Users\\Sayandeep Sinha\\Documents\\data.csv")

# %%
colums = ['Name', 'Measure']

# %%
data.columns = colums

# %% [markdown]
# Plot the data :

# %%
plt.plot(data.Measure);

# %% [markdown]
# find the outliers :

# %%
    
plt.boxplot(data.Measure, notch=1, manage_ticks=True, vert=True);   
# As we can see this data has a outlier.

# %% [markdown]
# find out  Î¼,Ïƒ,Ïƒ^2 :

# %%
    
    
# Mean:

# %%
data.Measure.mean()

# %% [markdown]
# Standard deviation :

# %%
    
np.std(data.Measure)

# %% [markdown]
# Variance :

# %%
    
    
np.var(data.Measure)
