# %% [markdown]
# ###########################:MISSING_VALUES:############################<br>
# ataset: Claimants.csv

# %% [markdown]
# Importing the necessary packages/dependencies  :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Loading the dataset From local directory  :

# %%
df = pd.read_csv("C:\\Users\\Sayandeep Sinha\\Documents\\claimants.csv")

# %%
df.isnull().values.any()

# %%
df.info()
# we are taking 1340 as complete count

# %%
df_null = df.isnull().value_counts()

# %% [markdown]
# Casenum,Attorny and Loss column has no missing value.

# %% [markdown]
# CLMSEX column:

# %%
 
percentage_missing_clmsex = (df.CLMSEX.isnull().sum()/(len(df)*1.0)*100)    
print(percentage_missing_clmsex) 
# As we can see there are only 0.89 % misiing value

# %%
df.CLMSEX.head(20)

# %%
df.CLMSEX.isnull().sum()

# %%
df.CLMSEX.loc[df.CLMSEX.isnull()]

# %% [markdown]
# The values are Boolean series, hence we can impute values by replacing the median or we can<br>
# Fill the backward data :

# %%
    
df.CLMSEX = df.CLMSEX.bfill() # filling the NA's with backward value of the particular value.

# %% [markdown]
# Checking the misiing value if present:

# %%
df.CLMSEX.notnull().sum()

# %% [markdown]
# CLMINSUR column:

# %%
    
percentage_missing_clminsur = (df.CLMINSUR.isnull().sum()/(len(df)*1.0)*100)    
print(percentage_missing_clminsur)

# %% [markdown]
# As we can see there are only 3.06 % misiing value

# %%
df.CLMINSUR.head(20)

# %%
df.CLMINSUR.isnull().sum()

# %%
df.CLMINSUR.loc[df.CLMINSUR.isnull()]

# %% [markdown]
# The values are Boolean series, hence we can impute values by replacing the median or we can<br>
# Fill the backward data :

# %%
    
df.CLMINSUR = df.CLMINSUR.bfill() # filling the NA's with backward value of the particular value.

# %% [markdown]
# Checking the misiing value if present:

# %%
    
df.CLMINSUR.notnull().sum()

# %% [markdown]
# Seatbelt column:

# %%
    
percentage_missing_seatbelt = (df.SEATBELT.isnull().sum()/(len(df)*1.0)*100)    
print(percentage_missing_seatbelt)

# %% [markdown]
# As we can see there are only 3.58 % misiing value

# %%
df.SEATBELT.head(20)

# %%
df.SEATBELT.isnull().sum()

# %%
df.SEATBELT.loc[df.SEATBELT.isnull()]

# %% [markdown]
# The values are Boolean series, hence we can impute values by replacing the median or we can<br>
# Fill the backward data :

# %%
    
df.SEATBELT = df.SEATBELT.bfill() # filling the NA's with backward value of the particular value.

# %% [markdown]
# Checking the misiing value if present:

# %%
    
df.SEATBELT.notnull().sum()

# %% [markdown]
# CLMAGE  column:

# %%
    
percentage_missing_CLMAGE  = (df.CLMAGE.isnull().sum()/(len(df)*1.0)*100)    
print(percentage_missing_CLMAGE )

# %% [markdown]
# As we can see there are only 14.10 % misiing value

# %%
df.CLMAGE.head(20)

# %%
df.CLMAGE.isnull().sum()

# %%
df.CLMAGE.loc[df.SEATBELT.isnull()]
    
df.CLMAGE.describe()

# %%
df.CLMAGE.median()

# %% [markdown]
# The values are series, hence we can impute values by replacing the mean :<br>
# Imputing the mean values :

# %%
df.CLMAGE = df.CLMAGE.fillna(df.CLMAGE.mean()) # filling the NA's with mean value of the column.

# %%
df.CLMAGE.dtypes

# %%
df.CLMAGE = df.CLMAGE.astype('int64') # changing the data types from float to int
    
# Checking the misiing value if present: 
    
df.CLMAGE.notnull().sum()
